    "0901500011125", "090150001113A", "0901500011144", "0901500011178", "0901500011182",
    "0901500011197", "090150001120A", "0901500011214", "0901500011229", "0901500011233",
    "0901500011248", "0901500011252", "0901500011303", "0901500011318", "0901500011322",
    "0901500011337", "0901500011341", "0901500011356", "0901500011360", "0901500011375",
    "090150001138A", "0901500011394", "0901500011411", "0901500011426", "0901500011430",
    "0901500011445", "090150001145A", "0901500011464", "0901500011479", "0901500011483",
    "0901500011498", "0901500011534", "0901500011549", "0901600010798", "0901600010891",
    "0901600010957", "0901600010961", "0901600010976", "0901600010980", "0901600010995",
    "090160001100A", "0901600011014", "0901600011029", "0901600011067", "0901600011071",
    "0901600011086", "0901600011090", "0901600011103", "0901600011118", "0901600011122",
    "0901600011137", "0901600011141", "0901600011156", "0901600011160", "0901600011175",
    "090160001118A", "0901600011194", "0901600011207", "0901600011211", "0901600011226"
]

# Filtrar solo las filas que tienen los microcodes deseados
df_gasto_cdmx_filtrado = df_gasto[df_gasto["MICROCODE"].isin(microcodes_filtrar)]

# Verificar el resultado
print(df_gasto_cdmx_filtrado.head())
print(f"Total de filas después del filtrado: {len(df_gasto_cdmx_filtrado)}")
# Out:
#       CTRYCODE      MICROCODE            NAME   P_T     P_PRM     PP_MIO  \
# 12451       MX  0901000010012  Álvaro Obregón  1752  0.013646  21.824542
# 12452       MX  0901000010027  Álvaro Obregón  2557  0.019916  33.300177
# 12453       MX  0901000010031  Álvaro Obregón  3504  0.027293  40.023992
# 12454       MX  0901000010046  Álvaro Obregón  5429  0.042287  52.849749
# 12455       MX  0901000010050  Álvaro Obregón  4222  0.032885  46.214241
#
#          PP_PRM       PP_EURO       PP_CI  CSP01_MIO  ...  CSP18_EURO  \
# 12451  0.024540  12456.930584  179.830320   4.258657  ...  260.098044
# 12452  0.037444  13023.143294  188.004260   6.398951  ...  266.245844
# 12453  0.045004  11422.372199  164.895263   8.105035  ...  242.811555
# 12454  0.059426   9734.711545  140.531913  11.691558  ...  224.903666
# 12455  0.051965  10946.054174  158.019057   9.730819  ...  238.425728
#
#          CSP18_CI  CSP19_MIO  CSP19_PRM  CSP19_EURO    CSP19_CI  CSP20_MIO  \
# ...

# %%
# Lista de columnas a eliminar
columnas_a_eliminar = [
    "CTRYCODE",
    "PP_MIO", "PP_PRM", "PP_CI",
    "CSP01_MIO", "CSP01_PRM", "CSP01_CI",
    "CSP02_MIO", "CSP02_PRM", "CSP02_CI",
    "CSP03_MIO", "CSP03_PRM", "CSP03_CI",
    "CSP04_MIO", "CSP04_PRM", "CSP04_CI",
    "CSP05_MIO", "CSP05_PRM", "CSP05_CI",
    "CSP06_MIO", "CSP06_PRM", "CSP06_CI",
    "CSP07_MIO", "CSP07_PRM", "CSP07_CI",
    "CSP08_MIO", "CSP08_PRM", "CSP08_CI",
    "CSP09_MIO", "CSP09_PRM", "CSP09_CI",
    "CSP10_MIO", "CSP10_PRM", "CSP10_CI",
    "CSP11_MIO", "CSP11_PRM", "CSP11_CI",
    "CSP12_MIO", "CSP12_PRM", "CSP12_CI",
    "CSP13_MIO", "CSP13_PRM", "CSP13_CI",
    "CSP14_MIO", "CSP14_PRM", "CSP14_CI",
    "CSP15_MIO", "CSP15_PRM", "CSP15_CI",
    "CSP16_MIO", "CSP16_PRM", "CSP16_CI",
    "CSP17_MIO", "CSP17_PRM", "CSP17_CI",
    "CSP18_MIO", "CSP18_PRM", "CSP18_CI",
    "CSP19_MIO", "CSP19_PRM", "CSP19_CI",
    "CSP20_MIO", "CSP20_PRM", "CSP20_CI",
    "NAME"
]

# Eliminar las columnas del DataFrame
df_gasto_cdmx_filtrado = df_gasto_cdmx_filtrado.drop(columns=columnas_a_eliminar, errors="ignore")

# Mostrar las primeras filas para verificar
df_gasto_cdmx_filtrado.head()
# Out:
#            MICROCODE   P_T     P_PRM       PP_EURO   CSP01_EURO  CSP02_EURO  \
# 12451  0901000010012  1752  0.013646  12456.930584  2430.740342  195.081621
# 12452  0901000010027  2557  0.019916  13023.143294  2502.522747  202.092066
# 12453  0901000010031  3504  0.027293  11422.372199  2313.080638  190.028855
# 12454  0901000010046  5429  0.042287   9734.711545  2153.538022  175.197425
# 12455  0901000010050  4222  0.032885  10946.054174  2304.788958  191.136429
#
#        CSP03_EURO  CSP04_EURO  CSP05_EURO  CSP06_EURO  ...  CSP11_EURO  \
# 12451   77.073280  221.246609   84.423875   93.583074  ...  277.300066
# 12452   78.870581  226.429898   86.841538   96.259356  ...  284.095080
# 12453   71.165398  211.906113   81.833004   92.379804  ...  256.624330
# 12454   66.162228  198.159868   77.004333   86.801471  ...  236.769218
# 12455   70.862568  208.841914   81.336018   92.209328  ...  252.014270
#
#        CSP12_EURO  CSP13_EURO  CSP14_EURO  CSP15_EURO  CSP16_EURO  CSP17_EURO  \
# ...

# %%
# Renombrar la columna MICROCODE a MICROCODE_MUN
df_gasto_cdmx_filtrado = df_gasto_cdmx_filtrado.rename(columns={"MICROCODE": "MICROCODE_MUN"})

# Añadir el sufijo "_TG" a todas las demás columnas excepto MICROCODE_MUN
df_gasto_cdmx_filtrado = df_gasto_cdmx_filtrado.rename(
    columns={col: col + "_TG" for col in df_gasto_cdmx_filtrado.columns if col != "MICROCODE_MUN"}
)

# Verificar los cambios
print(df_gasto_cdmx_filtrado.head())
print(df_gasto_cdmx_filtrado.columns)
# Out:
#        MICROCODE_MUN  P_T_TG  P_PRM_TG    PP_EURO_TG  CSP01_EURO_TG  \
# 12451  0901000010012    1752  0.013646  12456.930584    2430.740342
# 12452  0901000010027    2557  0.019916  13023.143294    2502.522747
# 12453  0901000010031    3504  0.027293  11422.372199    2313.080638
# 12454  0901000010046    5429  0.042287   9734.711545    2153.538022
# 12455  0901000010050    4222  0.032885  10946.054174    2304.788958
#
#        CSP02_EURO_TG  CSP03_EURO_TG  CSP04_EURO_TG  CSP05_EURO_TG  \
# 12451     195.081621      77.073280     221.246609      84.423875
# 12452     202.092066      78.870581     226.429898      86.841538
# 12453     190.028855      71.165398     211.906113      81.833004
# 12454     175.197425      66.162228     198.159868      77.004333
# 12455     191.136429      70.862568     208.841914      81.336018
#
#        CSP06_EURO_TG  ...  CSP11_EURO_TG  CSP12_EURO_TG  CSP13_EURO_TG  \
# 12451      93.583074  ...     277.300066     247.714130     190.750995
# ...

# %%
# Guardar el DataFrame en un archivo Excel
output_path = "Tipología_de_gasto_sample.xlsx"  # Nombre del archivo de salida
df_gasto_cdmx_filtrado.to_excel(output_path, index=False)

print(f"Archivo exportado correctamente: {output_path}")
# Out:
# Archivo exportado correctamente: Tipología_de_gasto_sample.xlsx
